# %% [markdown]
# # Project: planning my next holidays ☀️
#
# Let's put your dataset in a postgreSQL database on Amazon RDS ! Then, you can use the SQL syntax to make requests and decide where you'll go for your holidays. 😎

# %%
# !pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.8.6-cp38-cp38-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 7.5 MB/s eta 0:00:01
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.8.6

# %% [markdown]
# 1. Read the `.csv` files containing information about cities and hotels:

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
cities = pd.read_csv('https://m03-jedha-project-040121.s3.amazonaws.com/cities.csv')  # pd.read_csv('res/1_destinations.csv')
hotels = pd.read_csv('https://m03-jedha-project-040121.s3.amazonaws.com/cities.csv')  # pd.read_csv('res/3_hotels.csv')

# %%
cities.head()
# Out:
#    city_id                          name   latitude  longitude main_weather  \
# 0        8                    Strasbourg  48.584614   7.750713       Clouds
# 1        9  Chateau du Haut Koenigsbourg  48.249523   7.345492       Clouds
# 2       10                        Colmar  48.077752   7.357964       Clouds
# 3       11                     Eguisheim  48.044797   7.307962       Clouds
# 4        0             Mont Saint Michel  48.635856  -1.512610       Clouds
#
#    expected_rain  day_temperature  rank  inverted_rank
# 0         0.1848          2.30125     1             35
# 1         0.4344         -0.00625     2             34
# 2         1.8291          2.18000     3             33
# 3         2.4012          2.15500     4             32
# 4         2.4269          4.27375     5             31

# %%
hotels.head()
# Out:
#    city_id    city_name  hotel_id                                  name  \
# 0       34  La Rochelle         0  Lagrange Apart'Hotel l’Escale Marine
# 1       34  La Rochelle         1               Appart'City La Rochelle
# 2       34  La Rochelle         2           ibis La Rochelle Vieux Port
# 3       34  La Rochelle         3               ATHOME RESIDENCE ET SPA
# 4       34  La Rochelle         4        Best Western Premier Masqhotel
#
#                                                  url   latitude  longitude  \
# 0  https://www.booking.com/hotel/fr/l-escale-mari...  46.151070  -1.154863
# 1  https://www.booking.com/hotel/fr/appart-city-c...  46.158447  -1.141012
# 2  https://www.booking.com/hotel/fr/ibis-la-roche...  46.155829  -1.148558
# 3  https://www.booking.com/hotel/fr/athome-reside...  46.145995  -1.152398
# 4  https://www.booking.com/hotel/fr/masqhotel.fr....  46.154837  -1.145056
#
#    score                                        description
# 0    7.2  Le Lagrange Apart'Hotel l’Escale Marine vous a...
# 1    7.4  L’Appart'City La Rochelle se trouve à 10 minut...
# 2    8.3  Situé dans le quartier du Vieux-Port, dans le ...
# 3    8.1  Situé à La Rochelle, l'établissement ATHOME RE...
# 4    8.7  Le Best Western Masqhotel est un hôtel design ...

# %% [markdown]
# 2. Create and configure a RDS instance in your AWS account.
#
# 3. Use SQLAlchemy to create an engine that is connected to the remote database:

# %%
# Replace HOSTNAME by AWS RDS Endpoint, USERNAME and PASSWORD by its credentials
engine = create_engine("postgresql+psycopg2://USERNAME:PASSWORD@HOSTNAME/postgres", echo=True)

# %% [markdown]
# 4. Create two tables in your remote database : `cities` and `hotels`, each one containing the information from the different `.csv` files you saved last time.

# %%
cities.to_sql("cities", engine)
hotels.to_sql("hotels", engine)
# Out:
# 2021-01-04 15:37:47,497 INFO sqlalchemy.engine.base.Engine select version()
# 2021-01-04 15:37:47,499 INFO sqlalchemy.engine.base.Engine {}
# 2021-01-04 15:37:47,519 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2021-01-04 15:37:47,520 INFO sqlalchemy.engine.base.Engine {}
# 2021-01-04 15:37:47,538 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-01-04 15:37:47,539 INFO sqlalchemy.engine.base.Engine {}
# 2021-01-04 15:37:47,553 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-01-04 15:37:47,554 INFO sqlalchemy.engine.base.Engine {}
# 2021-01-04 15:37:47,561 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2021-01-04 15:37:47,562 INFO sqlalchemy.engine.base.Engine {}
# 2021-01-04 15:37:47,575 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-01-04 15:37:47,577 INFO sqlalchemy.engine.base.Engine {'name': 'cities'}
# 2021-01-04 15:37:47,605 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE cities (
# 	index BIGINT,
# 	city_id BIGINT,
# 	name TEXT,
# 	latitude FLOAT(53),
# 	longitude FLOAT(53),
# 	main_weather TEXT,
# 	expected_rain FLOAT(53),
# 	day_temperature FLOAT(53),
# 	rank BIGINT,
# 	inverted_rank BIGINT
# )
#
#
# 2021-01-04 15:37:47,606 INFO sqlalchemy.engine.base.Engine {}
# 2021-01-04 15:37:47,661 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-01-04 15:37:47,671 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_cities_index ON cities (index)
# 2021-01-04 15:37:47,672 INFO sqlalchemy.engine.base.Engine {}
# 2021-01-04 15:37:47,692 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-01-04 15:37:47,703 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-01-04 15:37:47,705 INFO sqlalchemy.engine.base.Engine INSERT INTO cities (index, city_id, name, latitude, longitude, main_weather, expected_rain, day_temperature, rank, inverted_rank) VALUES (%(index)s, %(city_id)s, %(name)s, %(latitude)s, %(longitude)s, %(main_weather)s, %(expected_rain)s, %(day_temperature)s, %(rank)s, %(inverted_rank)s)
# 2021-01-04 15:37:47,707 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'city_id': 8, 'name': 'Strasbourg', 'latitude': 48.584614, 'longitude': 7.750712700000001, 'main_weather': 'Clouds', 'expected_rain': 0.1848, 'day_temperature': 2.30125, 'rank': 1, 'inverted_rank': 35}, {'index': 1, 'city_id': 9, 'name': 'Chateau du Haut Koenigsbourg', 'latitude': 48.249522600000006, 'longitude': 7.345492299999999, 'main_weather': 'Clouds', 'expected_rain': 0.4344, 'day_temperature': -0.006250000000000004, 'rank': 2, 'inverted_rank': 34}, {'index': 2, 'city_id': 10, 'name': 'Colmar', 'latitude': 48.07775170000001, 'longitude': 7.3579641, 'main_weather': 'Clouds', 'expected_rain': 1.8291, 'day_temperature': 2.18, 'rank': 3, 'inverted_rank': 33}, {'index': 3, 'city_id': 11, 'name': 'Eguisheim', 'latitude': 48.0447968, 'longitude': 7.3079618, 'main_weather': 'Clouds', 'expected_rain': 2.4012, 'day_temperature': 2.155, 'rank': 4, 'inverted_rank': 32}, {'index': 4, 'city_id': 0, 'name': 'Mont Saint Michel', 'latitude': 48.6358559, 'longitude': -1.5126096000000002, 'main_weather': 'Clouds', 'expected_rain': 2.4269, 'day_temperature': 4.27375, 'rank': 5, 'inverted_rank': 31}, {'index': 5, 'city_id': 4, 'name': 'Rouen', 'latitude': 49.4404591, 'longitude': 1.0939658, 'main_weather': 'Clouds', 'expected_rain': 3.1043, 'day_temperature': 3.4137500000000003, 'rank': 6, 'inverted_rank': 30}, {'index': 6, 'city_id': 34, 'name': 'La Rochelle', 'latitude': 46.1591126, 'longitude': -1.1520434, 'main_weather': 'Clouds', 'expected_rain': 3.49, 'day_temperature': 4.22, 'rank': 7, 'inverted_rank': 29}, {'index': 7, 'city_id': 7, 'name': 'Lille', 'latitude': 50.636565399999995, 'longitude': 3.0635282000000004, 'main_weather': 'Clouds', 'expected_rain': 3.7866, 'day_temperature': 3.5125, 'rank': 8, 'inverted_rank': 28}  ... displaying 10 of 35 total bound parameter sets ...  {'index': 33, 'city_id': 26, 'name': 'Saintes Maries de la mer', 'latitude': 43.4522771, 'longitude': 4.4287171999999995, 'main_weather': 'Rain', 'expected_rain': 45.88510000000001, 'day_temperature': 5.731250000000001, 'rank': 34, 'inverted_rank': 2}, {'index': 34, 'city_id': 18, 'name': 'Bormes les Mimosas', 'latitude': 43.1506968, 'longitude': 6.341928500000001, 'main_weather': 'Rain', 'expected_rain': 83.99619999999999, 'day_temperature': 7.524999999999999, 'rank': 35, 'inverted_rank': 1})
# 2021-01-04 15:37:47,928 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-01-04 15:37:47,939 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-01-04 15:37:47,940 INFO sqlalchemy.engine.base.Engine {'name': 'hotels'}
# 2021-01-04 15:37:47,961 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE hotels (
# 	index BIGINT,
# 	city_id BIGINT,
# 	city_name TEXT,
# 	hotel_id BIGINT,
# 	name TEXT,
# 	url TEXT,
# 	latitude FLOAT(53),
# 	longitude FLOAT(53),
# 	score FLOAT(53),
# 	description TEXT
# )
#
#
# 2021-01-04 15:37:47,962 INFO sqlalchemy.engine.base.Engine {}
# 2021-01-04 15:37:47,980 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-01-04 15:37:47,988 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_hotels_index ON hotels (index)
# 2021-01-04 15:37:47,989 INFO sqlalchemy.engine.base.Engine {}
# 2021-01-04 15:37:48,005 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-01-04 15:37:48,016 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-01-04 15:37:48,028 INFO sqlalchemy.engine.base.Engine INSERT INTO hotels (index, city_id, city_name, hotel_id, name, url, latitude, longitude, score, description) VALUES (%(index)s, %(city_id)s, %(city_name)s, %(hotel_id)s, %(name)s, %(url)s, %(latitude)s, %(longitude)s, %(score)s, %(description)s)
# 2021-01-04 15:37:48,030 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'city_id': 34, 'city_name': 'La Rochelle', 'hotel_id': 0, 'name': "Lagrange Apart'Hotel l’Escale Marine", 'url': 'https://www.booking.com/hotel/fr/l-escale-marine.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaBWIAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgS4AtfDtv8FwAIB0gIkMTF ... (146 characters truncated) ... ildren=0&hapos=1&hpos=1&no_rooms=1&sr_order=popularity&srepoch=1609408984&srpvid=16e146ac33390123&ucfs=1&from=searchresults;highlight_room=#hotelTmpl', 'latitude': 46.151070119615795, 'longitude': -1.15486329021303, 'score': 7.2, 'description': "Le Lagrange Apart'Hotel l’Escale Marine vous accueille à La Rochelle, à côté du port des Minimes. Cette résidence possède une piscine couverte chauffée ainsi qu’un centre de bien-être. "}, {'index': 1, 'city_id': 34, 'city_name': 'La Rochelle', 'hotel_id': 1, 'name': "Appart'City La Rochelle", 'url': 'https://www.booking.com/hotel/fr/appart-city-cap-affaires-la-rochelle.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaBWIAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAg ... (167 characters truncated) ... ildren=0&hapos=2&hpos=2&no_rooms=1&sr_order=popularity&srepoch=1609408984&srpvid=16e146ac33390123&ucfs=1&from=searchresults;highlight_room=#hotelTmpl', 'latitude': 46.1584466937086, 'longitude': -1.1410117149353, 'score': 7.4, 'description': "L’Appart'City La Rochelle se trouve à 10 minutes à pied de la gare de La Rochelle ainsi qu'à 15 minutes du Vieux-Port et de la vieille ville. "}, {'index': 2, 'city_id': 34, 'city_name': 'La Rochelle', 'hotel_id': 2, 'name': 'ibis La Rochelle Vieux Port', 'url': 'https://www.booking.com/hotel/fr/ibis-la-rochelle-vieux-port.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaBWIAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgS4AtfDtv8 ... (158 characters truncated) ... ildren=0&hapos=3&hpos=3&no_rooms=1&sr_order=popularity&srepoch=1609408984&srpvid=16e146ac33390123&ucfs=1&from=searchresults;highlight_room=#hotelTmpl', 'latitude': 46.1558294, 'longitude': -1.14855799999998, 'score': 8.3, 'description': "Situé dans le quartier du Vieux-Port, dans le centre-ville, l'ibis La Rochelle Vieux Port propose une connexion Wi-Fi gratuite dans l'ensemble des locaux, un bar, ainsi que des chambres adaptées aux..."}, {'index': 3, 'city_id': 34, 'city_name': 'La Rochelle', 'hotel_id': 3, 'name': 'ATHOME RESIDENCE ET SPA', 'url': 'https://www.booking.com/hotel/fr/athome-residence-et-spa.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaBWIAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgS4AtfDtv8FwAI ... (154 characters truncated) ... ildren=0&hapos=4&hpos=4&no_rooms=1&sr_order=popularity&srepoch=1609408984&srpvid=16e146ac33390123&ucfs=1&from=searchresults;highlight_room=#hotelTmpl', 'latitude': 46.145995, 'longitude': -1.152398, 'score': 8.1, 'description': "Situé à La Rochelle, l'établissement ATHOME RESIDENCE ET SPA propose une connexion Wi-Fi gratuite, un bar, un salon commun et un jardin. "}, {'index': 4, 'city_id': 34, 'city_name': 'La Rochelle', 'hotel_id': 4, 'name': 'Best Western Premier Masqhotel', 'url': 'https://www.booking.com/hotel/fr/masqhotel.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaBWIAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgS4AtfDtv8FwAIB0gIkMTFlMDRlN ... (140 characters truncated) ... ildren=0&hapos=5&hpos=5&no_rooms=1&sr_order=popularity&srepoch=1609408984&srpvid=16e146ac33390123&ucfs=1&from=searchresults;highlight_room=#hotelTmpl', 'latitude': 46.1548367218857, 'longitude': -1.14505648612976, 'score': 8.7, 'description': 'Le Best Western Masqhotel est un hôtel design situé à 5 minutes de marche du vieux port de La Rochelle. Il possède des chambres contemporaines, un bar-salon et une connexion Wi-Fi gratuite. '}, {'index': 5, 'city_id': 34, 'city_name': 'La Rochelle', 'hotel_id': 5, 'name': 'Hôtel Kyriad La Rochelle Centre Ville', 'url': 'https://www.booking.com/hotel/fr/kyriad-la-rochelle-centre.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaBWIAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgS4AtfDtv8Fw ... (156 characters truncated) ... ildren=0&hapos=6&hpos=6&no_rooms= ...
# 2021-01-04 15:37:54,015 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# 5. Optional: use PGAdmin to explore the database
#
# 6. Use SQL syntax to make a request that will help you get the list of the 30 best places to go (among all cities and hotels). 😎

# %%
statement = "SELECT city_name, main_weather, day_temperature, hotels.name, description, score, url \
             FROM cities \
             INNER JOIN hotels \
             ON cities.city_id = hotels.city_id \
             WHERE rank=1 AND score IS NOT NULL \
             ORDER BY score DESC \
             LIMIT 30"

best_places = pd.read_sql(statement, engine)
# Out:
# 2021-01-04 15:38:26,010 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-01-04 15:38:26,012 INFO sqlalchemy.engine.base.Engine {'name': 'SELECT city_name, main_weather, day_temperature, hotels.name, description, score, url              FROM cities              INNER JOIN hotels              ON cities.city_id = hotels.city_id              WHERE rank=1 AND score IS NOT NULL              ORDER BY score DESC              LIMIT 30'}
# 2021-01-04 15:38:26,033 INFO sqlalchemy.engine.base.OptionEngine SELECT city_name, main_weather, day_temperature, hotels.name, description, score, url              FROM cities              INNER JOIN hotels              ON cities.city_id = hotels.city_id              WHERE rank=1 AND score IS NOT NULL              ORDER BY score DESC              LIMIT 30
# 2021-01-04 15:38:26,034 INFO sqlalchemy.engine.base.OptionEngine {}

# %%
display(best_places)
# Out:
#      city_name main_weather  day_temperature  \
# 0   Strasbourg       Clouds          2.30125
# 1   Strasbourg       Clouds          2.30125
# 2   Strasbourg       Clouds          2.30125
# 3   Strasbourg       Clouds          2.30125
# 4   Strasbourg       Clouds          2.30125
# 5   Strasbourg       Clouds          2.30125
# 6   Strasbourg       Clouds          2.30125
# 7   Strasbourg       Clouds          2.30125
# 8   Strasbourg       Clouds          2.30125
# 9   Strasbourg       Clouds          2.30125
# 10  Strasbourg       Clouds          2.30125
# 11  Strasbourg       Clouds          2.30125
# 12  Strasbourg       Clouds          2.30125
# 13  Strasbourg       Clouds          2.30125
# 14  Strasbourg       Clouds          2.30125
# 15  Strasbourg       Clouds          2.30125
# 16  Strasbourg       Clouds          2.30125
# 17  Strasbourg       Clouds          2.30125
# 18  Strasbourg       Clouds          2.30125
# 19  Strasbourg       Clouds          2.30125
# 20  Strasbourg       Clouds          2.30125
# 21  Strasbourg       Clouds          2.30125
# 22  Strasbourg       Clouds          2.30125
# 23  Strasbourg       Clouds          2.30125
# 24  Strasbourg       Clouds          2.30125
# 25  Strasbourg       Clouds          2.30125
# 26  Strasbourg       Clouds          2.30125
# 27  Strasbourg       Clouds          2.30125
# 28  Strasbourg       Clouds          2.30125
# 29  Strasbourg       Clouds          2.30125
#
#                                                  name  \
# 0     Le Carré d'or - Appartement avec vue Cathédrale
# 1   Strasbourg Ambiance Nature - parking, tram, 8 ...
# 2                                 Appartement Rotonde
# 3   Appartement à Strasbourg Maison des écluses F3...
# 4                                               LE 39
# 5    Like'Home 3 pièces en plein centre de Strasbourg
# 6                      Goodtime Apartments Strasbourg
# 7                              Quai 17 Maison d'hôtes
# 8                                     Bel appartement
# 9                               Le Carré Confidentiel
# 10     Au cœur de Strasbourg, 3 pièces vue sur l'Ill!
# 11                                          L'Atelier
# 12                       Appartement COSY Hypercentre
# 13  LE NID DE L'ILL, Magnifique Duplex Cosy Petite...
# 14                                          Le Dunant
# 15         Carpe Diem Home - Au pied de la Cathédrale
# 16                     L'Appart du Quai avec Terrasse
# 17  Maison d'hôtes de coeur et d'exception - Du co...
# 18                               Le Carré des oiseaux
# 19                                Le Carré des fleurs
# 20                            Le Nid de la Cathedrale
# 21                                         AULOUISON2
# 22                         Appartement L'Ill au Sable
# 23                                         LE LOFT 67
# 24                                L'appart Du Général
# 25            Cosy Kleber - 80m2 in the HEART of town
# 26      LIFE RENAISSANCE - New Concept - Place Kléber
# 27                    L'Appartement de l'Observatoire
# 28                                        Go to Stras
# 29                    Appartement Le bain aux plantes
#
#                                           description  score  \
# 0   Situé dans le centre-ville de Strasbourg, à 30...    9.9
# 1   Agrémenté d'une terrasse, le Strasbourg Ambian...    9.9
# 2   L'Appartement Rotonde est situé à Strasbourg, ...    9.8
# 3   Située à Strasbourg, à 3,1 km du quartier de l...    9.8
# 4   LE 39 is situated in Strasbourg, 500 m from St...    9.8
# 5   Situé dans le quartier de la Bourse-Esplanade ...    9.7
# 6   Le Goodtime Apartments Strasbourg propose des ...    9.7
# 7   Le Quai 17 se trouve à 6 km du parc du château...    9.7
# 8   Situé à Strasbourg, en Alsace, le Bel appartem...    9.7
# 9   Offrant une vue sur le jardin, l'établissement...    9.7
# 10  Installé dans le centre-ville de Strasbourg, l...    9.7
# 11  Situé à 200 mètres de la Petite France à Stras...    9.6
# 12  Situé dans le centre-ville de Strasbourg, à se...    9.6
# 13  Situé dans un quartier central de Strasbourg, ...    9.6
# 14  Situé à Strasbourg, à 200 mètres de la Petite ...    9.6
# 15  Proposant des hébergements avec une cuisine, l...    9.6
# 16  Installé à environ 400 mètres du marché de Noë...    9.6
# 17  Installée à 1,2 km du parc de l'Orangerie, la ...    9.6
# 18  Doté d’un jardin, Le Carré des oiseaux propose...    9.6
# 19  Situé à Strasbourg, à 1,4 km du musée d'histoi...    9.5
# 20  Offrant une vue sur la ville, l'établissement ...    9.5
# 21  Situé à Strasbourg, à moins de 700 mètres du p...    9.5
# 22  Occupant un bâtiment du XIXe siècle à Strasbou...    9.5
# 23  Situé dans le centre de Strasbourg, à moins de...    9.5
# 24  Situé à Strasbourg l’établissement L'appart Du...    9.5
# 25  Situé dans un quartier central de Strasbourg, ...    9.5
# 26  Le LIFE RENAISSANCE - New Concept - Place Kléb...    9.4
# 27  L'Appartement de l'Observatoire est situé à St...    9.4
# 28  Offrant une vue sur la ville, le Go to Stras e...    9.4
# 29  L'Appartement Le bain aux plantes est situé da...    9.4
#
#                                                   url
# 0   https://www.booking.com/hotel/fr/golden-square...
# 1   https://www.booking.com/hotel/fr/strasbourg-lo...
# 2   https://www.booking.com/hotel/fr/appartement-r...
# 3   https://www.booking.com/hotel/fr/la-maison-des...
# 4   https://www.booking.com/hotel/fr/le-39-strasbo...
# 5   https://www.booking.com/hotel/fr/joli-3-pieces...
# 6   https://www.booking.com/hotel/fr/time-opera-st...
# 7   https://www.booking.com/hotel/fr/quai-17-maiso...
# 8   https://www.booking.com/hotel/fr/bel-apparteme...
# 9   https://www.booking.com/hotel/fr/le-carre-conf...
# 10  https://www.booking.com/hotel/fr/au-coeur-de-s...
# 11  https://www.booking.com/hotel/fr/l-39-atelier-...
# 12  https://www.booking.com/hotel/fr/appartement-c...
# 13  https://www.booking.com/hotel/fr/le-nid-de-l-3...
# 14  https://www.booking.com/hotel/fr/le-dunant-str...
# 15  https://www.booking.com/hotel/fr/carpe-diem-ho...
# 16  https://www.booking.com/hotel/fr/l-39-appart-d...
# 17  https://www.booking.com/hotel/fr/du-cota-c-de-...
# 18  https://www.booking.com/hotel/fr/le-carre-des-...
# 19  https://www.booking.com/hotel/fr/le-carre-des-...
# 20  https://www.booking.com/hotel/fr/le-nid-de-la-...
# 21  https://www.booking.com/hotel/fr/aulouison2.fr...
# 22  https://www.booking.com/hotel/fr/appartement-l...
# 23  https://www.booking.com/hotel/fr/le-loft-67-st...
# 24  https://www.booking.com/hotel/fr/l-39-appart-d...
# 25  https://www.booking.com/hotel/fr/cosy-kleber-9...
# 26  https://www.booking.com/hotel/fr/life-renaissa...
# 27  https://www.booking.com/hotel/fr/appartement-d...
# 28  https://www.booking.com/hotel/fr/go-to-stras.f...
# 29  https://www.booking.com/hotel/fr/le-bain-aux-p...
